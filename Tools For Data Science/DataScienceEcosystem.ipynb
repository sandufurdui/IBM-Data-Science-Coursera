# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized. The purpose is to demonstrate different text formats that can be used in Jupyter Notebook.

# %% [markdown]
# **Objectives:**
#
# * Explore popular languages for Data Science.
# * Understand the basics of deep learning using PyTorch.
# * Learn how to create and visualize data with Python libraries like Matplotlib and Seaborn.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. Julia
# 3. R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Sklearn
# 3. NumPy
# 4. Matplotlib
# 5. TensorFlow

# %% [markdown]
# | Data Science Tools   |
# | -------------------- |
# | Jupyter Notebooks    |
# | RStudio              |
# | VS Code (with Python) |

# %% [markdown]
# ##### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Alex Furdui
